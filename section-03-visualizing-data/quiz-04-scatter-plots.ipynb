# %% [markdown]
# ## Quiz 4: Scatter Plots

# %% [markdown]
# Which of the following is true for scatter plots?
#
# ![image.png](attachment:image.png)

# %% [markdown]
# The answer is **C** as both axes needs to be a numerical variable
